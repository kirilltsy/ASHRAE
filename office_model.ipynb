# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import keras
from keras.models import Sequential
from keras.layers import Dense
# Out:
# Using TensorFlow backend.

# %%
def reduce_mem_usage(df, verbose=True):
    numerics = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']
    start_mem = df.memory_usage().sum() / 1024**2    
    for col in df.columns:
        col_type = df[col].dtypes
        if col_type in numerics:
            c_min = df[col].min()
            c_max = df[col].max()
            if str(col_type)[:3] == 'int':
                if c_min > np.iinfo(np.int8).min and c_max < np.iinfo(np.int8).max:
                    df[col] = df[col].astype(np.int8)
                elif c_min > np.iinfo(np.int16).min and c_max < np.iinfo(np.int16).max:
                    df[col] = df[col].astype(np.int16)
                elif c_min > np.iinfo(np.int32).min and c_max < np.iinfo(np.int32).max:
                    df[col] = df[col].astype(np.int32)
                elif c_min > np.iinfo(np.int64).min and c_max < np.iinfo(np.int64).max:
                    df[col] = df[col].astype(np.int64)  
            else:
                if c_min > np.finfo(np.float16).min and c_max < np.finfo(np.float16).max:
                    df[col] = df[col].astype(np.float16)
                elif c_min > np.finfo(np.float32).min and c_max < np.finfo(np.float32).max:
                    df[col] = df[col].astype(np.float32)
                else:
                    df[col] = df[col].astype(np.float64)    
    end_mem = df.memory_usage().sum() / 1024**2
    if verbose: print('Mem. usage decreased to {:5.2f} Mb ({:.1f}% reduction)'.format(end_mem, 100 * (start_mem - end_mem) / start_mem))
    return df

# %%
def loadTrain():
    root = ''
    train_df = pd.read_csv(root + 'train.csv')
    train_df["timestamp"] = pd.to_datetime(train_df["timestamp"], format='%Y-%m-%d %H:%M:%S')
    train_df = reduce_mem_usage(train_df)

    weather_train_df = pd.read_csv(root + 'weather_train.csv')
    weather_train_df["timestamp"] = pd.to_datetime(weather_train_df["timestamp"], format='%Y-%m-%d %H:%M:%S')
    weather_train_df = reduce_mem_usage(weather_train_df)
    # test_df = pd.read_csv(root + 'test.csv')
    # test_df["hour"] = pd.to_datetime(test_df["timestamp"], format='%Y-%m-%d %H:%M:%S').dt.hour

    # weather_test_df = pd.read_csv(root + 'weather_test.csv')
    building_meta_df = pd.read_csv(root + 'building_metadata.csv')
    building_meta_df = reduce_mem_usage(building_meta_df)
    return (train_df,weather_train_df,building_meta_df)

# %%
def MergeT():
    train_df,weather_train_df,building_meta_df = loadTrain()
    b_data = pd.merge(train_df, building_meta_df, on='building_id')
    b_0 = b_data
    b = b_0.drop(columns=['primary_use', 'year_built', 'floor_count'])
    #b = b_0.drop(columns=['year_built', 'floor_count'])
    b = pd.merge(b, weather_train_df, on=['site_id','timestamp'])
    b['timestamp'] = pd.to_datetime(b["timestamp"], format='%Y-%m-%d %H:%M:%S')
    print("records:", len(b))

    b = b.drop(columns=['cloud_coverage', 'precip_depth_1_hr', 'sea_level_pressure', 
                'wind_direction', 'wind_speed'])

    b = b.dropna()
    print("records after dropping NaN:", len(b))

    b['Y'] = b['meter_reading'] / b['square_feet']*100
    b['workhour'] = np.abs(b['timestamp'].dt.hour - 12) < 5.5
    b['workday'] = b['timestamp'].dt.weekday < 5
    b = b.drop(columns = ["site_id","square_feet","timestamp","meter_reading"])
    print("rows in dataset:", len(b))
    b = b.astype({'building_id':int, 'workhour': int, 'workday': int})
    b = reduce_mem_usage(b)
    return b

# %%
def LoadTest():
    root = ''
    test_df = pd.read_csv(root + 'test.csv')
    test_df["timestamp"] = pd.to_datetime(test_df["timestamp"], format='%Y-%m-%d %H:%M:%S')
    test_df = reduce_mem_usage(test_df)

    weather_test_df = pd.read_csv(root + 'weather_test.csv')
    weather_test_df["timestamp"] = pd.to_datetime(weather_test_df["timestamp"], format='%Y-%m-%d %H:%M:%S')
    weather_test_df = reduce_mem_usage(weather_test_df)
    # test_df = pd.read_csv(root + 'test.csv')
    # test_df["hour"] = pd.to_datetime(test_df["timestamp"], format='%Y-%m-%d %H:%M:%S').dt.hour

    # weather_test_df = pd.read_csv(root + 'weather_test.csv')
    building_meta_df = pd.read_csv(root + 'building_metadata.csv')
    building_meta_df = reduce_mem_usage(building_meta_df)
    return (test_df,weather_test_df,building_meta_df)

def MergeTest():
    (test_df,weather_test_df,building_meta_df) = LoadTest()
    b_data = pd.merge(test_df, building_meta_df, on='building_id')
    b_0 = b_data
    print("records after merge building",len(b_0))
    b = b_0.drop(columns=['primary_use', 'year_built', 'floor_count'])
    b = pd.merge(b, weather_test_df, on=['site_id','timestamp'],how="left")
    b['timestamp'] = pd.to_datetime(b["timestamp"], format='%Y-%m-%d %H:%M:%S')
    print("records:", len(b))

    b = b.drop(columns=['cloud_coverage', 'precip_depth_1_hr', 'sea_level_pressure', 
                'wind_direction', 'wind_speed'])

    #b = b.dropna()
    print("records after dropping NaN:", len(b))

    b['workhour'] = np.abs(b['timestamp'].dt.hour - 12) < 5.5
    b['workday'] = b['timestamp'].dt.weekday < 5
    b = b.drop(columns = ["site_id","timestamp"])
    print("rows in dataset:", len(b))
    b = b.astype({'building_id':int, 'workhour': int, 'workday': int})
    b = reduce_mem_usage(b)
    return b

# %%
test_df = MergeTest()
test_df
# Out:
# Mem. usage decreased to 596.49 Mb (53.1% reduction)
# Mem. usage decreased to  6.08 Mb (68.1% reduction)
# Mem. usage decreased to  0.03 Mb (60.3% reduction)
# records after merge building 41697600
# records: 41697600
# records after dropping NaN: 41697600
# rows in dataset: 41697600
# Mem. usage decreased to 994.15 Mb (24.2% reduction)
#             row_id  building_id  meter  square_feet  air_temperature  \
# 0                0            0      0         7432        17.796875
# 1              129            0      0         7432        17.796875
# 2              258            0      0         7432        16.093750
# 3              387            0      0         7432        17.203125
# 4              516            0      0         7432        16.703125
# ...            ...          ...    ...          ...              ...
# 41697595  41692949         1448      0        92271              NaN
# 41697596  41693199         1448      0        92271              NaN
# 41697597  41697099         1448      0        92271              NaN
# 41697598  41697349         1448      0        92271              NaN
# 41697599  41697599         1448      0        92271              NaN
#
#           dew_temperature  workhour  workday
# 0               11.703125         0        0
# 1               12.796875         0        0
# 2               12.796875         0        0
# 3               13.296875         0        0
# 4               13.296875         0        0
# ...                   ...       ...      ...
# 41697595              NaN         1        1
# 41697596              NaN         1        1
# 41697597              NaN         0        1
# 41697598              NaN         0        1
# 41697599              NaN         1        1
#
# [41697600 rows x 8 columns]

# %%
train_df,weather_train_df,building_meta_df = loadTrain()
# Out:
# Mem. usage decreased to 289.19 Mb (53.1% reduction)
# Mem. usage decreased to  3.07 Mb (68.1% reduction)
# Mem. usage decreased to  0.03 Mb (60.3% reduction)

# %%
building_meta_df
# Out:
#       site_id  building_id                    primary_use  square_feet  \
# 0           0            0                      Education         7432
# 1           0            1                      Education         2720
# 2           0            2                      Education         5376
# 3           0            3                      Education        23685
# 4           0            4                      Education       116607
# ...       ...          ...                            ...          ...
# 1444       15         1444  Entertainment/public assembly        19619
# 1445       15         1445                      Education         4298
# 1446       15         1446  Entertainment/public assembly        11265
# 1447       15         1447            Lodging/residential        29775
# 1448       15         1448                         Office        92271
#
#       year_built  floor_count
# 0         2008.0          NaN
# 1         2004.0          NaN
# 2         1991.0          NaN
# 3         2002.0          NaN
# 4         1975.0          NaN
# ...          ...          ...
# 1444      1914.0          NaN
# 1445         NaN          NaN
# 1446      1997.0          NaN
# 1447      2001.0          NaN
# 1448      2001.0          NaN
#
# [1449 rows x 6 columns]

# %%
b = MergeT()
# Out:
# Mem. usage decreased to 289.19 Mb (53.1% reduction)
# Mem. usage decreased to  3.07 Mb (68.1% reduction)
# Mem. usage decreased to  0.03 Mb (60.3% reduction)
# records: 20125605
# records after dropping NaN: 20115960
# rows in dataset: 20115960
# Mem. usage decreased to 364.50 Mb (34.5% reduction)

# %%
b
# Out:
#           building_id  meter  air_temperature  dew_temperature         Y  \
# 0                   0      0        25.000000        20.000000  0.000000
# 1                   1      0        25.000000        20.000000  0.000000
# 2                   2      0        25.000000        20.000000  0.000000
# 3                   3      0        25.000000        20.000000  0.000000
# 4                   4      0        25.000000        20.000000  0.000000
# ...               ...    ...              ...              ...       ...
# 20125600         1400      1         1.700195         1.700195  0.072632
# 20125601         1400      1         2.800781         2.199219  0.118530
# 20125602         1400      1         5.601562         4.398438  0.152832
# 20125603         1400      1        11.101562         4.398438  0.114441
# 20125604         1400      1        15.000000         4.398438  0.077271
#
#           workhour  workday
# 0                0        1
# 1                0        1
# 2                0        1
# 3                0        1
# 4                0        1
# ...            ...      ...
# 20125600         1        1
# 20125601         1        1
# 20125602         1        1
# 20125603         1        1
# 20125604         1        1
#
# [20115960 rows x 7 columns]

# %%
resu = pd.DataFrame(columns = ["row_id","meter_reading"])
subres = pd.DataFrame(columns = ["row_id","meter_reading"])
for b_id in range(1449):
    for m in range(4):
        print("building",b_id)
        bld = b[b.building_id==b_id]
        bld = bld[bld.meter==m]
        bld = bld[bld.Y > 1e-10]
        bld = bld.drop(columns = ["building_id"])
        bld = bld.drop(columns = ["meter"])
        bld = bld.dropna()
        Y = bld.values[:,2]
        b_x = bld.drop(columns=['Y'])
        X = b_x.values / np.array([50, 10, 1, 1])
        if len(X)<128:
            p = lambda x:[[0.1]]
        else:
            model = Sequential()
            model.add(Dense(6, input_dim=4, activation="relu"))
            model.add(Dense(1, activation="relu"))
            adam = keras.optimizers.Adam(learning_rate=0.01, beta_1=0.9, beta_2=0.999, amsgrad=False)
            model.compile(loss="mean_squared_error", optimizer=adam, metrics=['accuracy'])
            model.fit(X, Y, epochs=50, batch_size=128, verbose = False)
            p = model.predict
            
        t = test_df[test_df.building_id == b_id]
        t = t[t.meter == m]
        t = t.drop(columns = ["meter","building_id"])
        l = []
        for i,row in t.iterrows():
            row_id, square_feet, air_temperature, dew_temperature, workhour, workday = row
            
            persqf = p(np.array([[air_temperature, dew_temperature, workhour, workday]]))[0][0]
            meter_reading = persqf * square_feet/100
            l.append(meter_reading)
        t["meter_reading"] = l
        t = t.drop(columns=["square_feet", "air_temperature", "dew_temperature", "workhour", "workday"])
        #resu = resu.append(t)
        subres = subres.append(t)
    if(b_id%50==48):
        print("saved")
        subres.to_csv("res/"+str(b_id)+".csv",index=False)
        subres = pd.DataFrame(columns = ["row_id","meter_reading"])
subres.to_csv("res/resufin.csv",index=False)
# Out:
# building 0
# building 0
# building 0
# building 0
# building 1
# building 1
# building 1
# building 1
# building 2
# building 2
# building 2
# building 2
# building 3
# building 3
# building 3
# building 3
# building 4
# building 4
# building 4
# building 4
# building 5
# building 5
# building 5
# building 5
# building 6
# building 6
# building 6
# building 6
# building 7
# building 7
# building 7
# building 7
# building 8
# building 8
# building 8
# building 8
# building 9
# building 9
# building 9
# building 9
# building 10
# building 10
# building 10
# building 10
# building 11
# building 11
# building 11
# building 11
# building 12
# building 12
# building 12
# building 12
# building 13
# building 13
# building 13
# building 13
# building 14
# building 14
# building 14
# building 14
# building 15
# building 15
# building 15
# building 15
# building 16
# building 16
# building 16
# building 16
# building 17
# building 17
# building 17
# building 17
# building 18
# building 18
# building 18
# building 18
# building 19
# building 19
# building 19
# building 19
# building 20
# building 20
# building 20
# building 20
# building 21
# building 21
# building 21
# building 21
# building 22
# building 22
# building 22
# building 22
# building 23
# building 23
# building 23
# building 23
# building 24
# building 24
# building 24
# building 24
# building 25
# building 25
# building 25
# building 25
# building 26
# building 26
# building 26
# building 26
# building 27
# building 27
# building 27
# building 27
# building 28
# building 28
# building 28
# building 28
# building 29
# building 29
# building 29
# building 29
# building 30
# building 30
# building 30
# building 30
# building 31
# building 31
# building 31
# building 31
# building 32
# building 32
# building 32
# building 32
# building 33
# building 33
# building 33
# building 33
# building 34
# building 34
# building 34
# building 34
# building 35
# building 35
# building 35
# building 35
# building 36
# building 36
# building 36
# building 36
# building 37
# building 37
# building 37
# building 37
# building 38
# building 38
# building 38
# building 38
# building 39
# building 39
# building 39
# building 39
# building 40
# building 40
# building 40
# building 40
# building 41
# building 41
# building 41
# building 41
# building 42
# building 42
# building 42
# building 42
# building 43
# building 43
# building 43
# building 43
# building 44
# building 44
# building 44
# building 44
# building 45
# building 45
# building 45
# building 45
# building 46
# building 46
# building 46
# building 46
# building 47
# building 47
# building 47
# building 47
# building 48
# building 48
# building 48
# building 48
# saved
# building 49
# building 49
# building 49
# building 49
# building 50
# building 50
# building 50
# building 50
# building 51
# building 51
# building 51
# building 51
# building 52
# building 52
# building 52
# building 52
# building 53
# building 53
# building 53
# building 53
# building 54
# building 54
# building 54
# building 54
# building 55
# building 55
# building 55
# building 55
# building 56
# building 56
# building 56
# building 56
# building 57
# building 57
# building 57
# building 57
# building 58
# building 58
# building 58
# building 58
# building 59
# building 59
# building 59
# building 59
# building 60
# building 60
# building 60
# building 60
# building 61
# building 61
# building 61
# building 61
# building 62
# building 62
# building 62
# building 62
# building 63
# building 63
# building 63
# building 63
# building 64
# building 64
# building 64
# building 64
# building 65
# building 65
# building 65
# building 65
# building 66
# building 66
# building 66
# building 66
# building 67
# building 67
# building 67
# building 67
# building 68
# building 68
# building 68
# building 68
# building 69
# building 69
# building 69
# building 69
# building 70
# building 70
# building 70
# building 70
# building 71
# building 71
# building 71
# building 71
# building 72
# building 72
# building 72
# building 72
# building 73
# building 73
# building 73
# building 73
# building 74
# building 74
# building 74
# building 74
# building 75
# building 75
# building 75
# building 75
# building 76
# building 76
# building 76
# building 76
# building 77
# building 77
# building 77
# building 77
# building 78
# building 78
# building 78
# building 78
# building 79
# building 79
# building 79
# building 79
# building 80
# building 80
# building 80
# building 80
# building 81
# building 81
# building 81
# building 81
# building 82
# building 82
# building 82
# building 82
# building 83
# building 83
# building 83
# building 83
# building 84
# building 84
# building 84
# building 84
# building 85
# building 85
# building 85
# building 85
# building 86
# building 86
# building 86
# building 86
# building 87
# building 87
# building 87
# building 87
# building 88
# building 88
# building 88
# building 88
# building 89
# building 89
# building 89
# building 89
# building 90
# building 90
# building 90
# building 90
# building 91
# building 91
# building 91
# building 91
# building 92
# building 92
# building 92
# building 92
# building 93
# building 93
# building 93
# building 93
# building 94
# building 94
# building 94
# building 94
# building 95
# building 95
# building 95
# building 95
# building 96
# building 96
# building 96
# building 96
# building 97
# building 97
# building 97
# building 97
# building 98
# building 98
# building 98
# building 98
# saved
# building 99
# building 99
# building 99
# building 99
# building 100
# building 100
# building 100
# building 100
# building 101
# building 101
# building 101
# building 101
# building 102
# building 102
# building 102
# building 102
# building 103
# building 103
# building 103
# building 103
# building 104
# building 104
# building 104
# building 104
# building 105
# building 105
# building 105
# building 105
# building 106
# building 106
# building 106
# building 106
# building 107
# building 107
# building 107
# building 107
# building 108
# building 108
# building 108
# building 108
# building 109
# building 109
# building 109
# building 109
# building 110
# building 110
# building 110
# building 110
# building 111
# building 111
# building 111
# building 111
# building 112
# building 112
# building 112
# building 112
# building 113
# building 113
# building 113
# building 113
# building 114
# building 114
# building 114
# building 114
# building 115
# building 115
# building 115
# building 115
# building 116
# building 116
# building 116
# building 116
# building 117
# building 117
# building 117
# building 117
# building 118
# building 118
# building 118
# building 118
# building 119
# building 119
# building 119
# building 119
# building 120
# building 120
# building 120
# building 120
# building 121
# building 121
# building 121
# building 121
# building 122
# building 122
# building 122
# building 122
# building 123
# building 123
# building 123
# building 123
# building 124
# building 124
# building 124
# building 124
# building 125
# building 125
# building 125
# building 125
# building 126
# building 126
# building 126
# building 126
# building 127
# building 127
# building 127
# building 127
# building 128
# building 128
# building 128
# building 128
# building 129
# building 129
# building 129
# building 129
# building 130
# building 130
# building 130
# building 130
# building 131
# building 131
# building 131
# building 131
# building 132
# building 132
# building 132
# building 132
# building 133
# building 133
# building 133
# building 133
# building 134
# building 134
# building 134
# building 134
# building 135
# building 135
# building 135
# building 135
# building 136
# building 136
# building 136
# building 136
# building 137
# building 137
# building 137
# building 137
# building 138
# building 138
# building 138
# building 138
# building 139
# building 139
# building 139
# building 139
# building 140
# building 140
# building 140
# building 140
# building 141
# building 141
# building 141
# building 141
# building 142
# building 142
# building 142
# building 142
# building 143
# building 143
# building 143
# building 143
# building 144
# building 144
# building 144
# building 144
# building 145
# building 145
# building 145
# building 145
# building 146
# building 146
# building 146
# building 146
# building 147
# building 147
# building 147
# building 147
# building 148
# building 148
# building 148
# building 148
# saved
# building 149
# building 149
# building 149
# building 149
# building 150
# building 150
# building 150
# building 150
# building 151
# building 151
# building 151
# building 151
# building 152
# building 152
# building 152
# building 152
# building 153
# building 153
# building 153
# building 153
# building 154
# building 154
# building 154
# building 154
# building 155
# building 155
# building 155
# building 155
# building 156
# building 156
# building 156
# building 156
# building 157
# building 157
# building 157
# building 157
# building 158
# building 158
# building 158
# building 158
# building 159
# building 159
# building 159
# building 159
# building 160
# building 160
# building 160
# building 160
# building 161
# building 161
# building 161
# building 161
# building 162
# building 162
# building 162
# building 162
# building 163
# building 163
# building 163
# building 163
# building 164
# building 164
# building 164
# building 164
# building 165
# building 165
# building 165
# building 165
# building 166
# building 166
# building 166
# building 166
# building 167
# building 167
# building 167
# building 167
# building 168
# building 168
# building 168
# building 168
# building 169
# building 169
# building 169
# building 169
# building 170
# building 170
# building 170
# building 170
# building 171
# building 171
# building 171
# building 171
# building 172
# building 172
# building 172
# building 172
# building 173
# building 173
# building 173
# building 173
# building 174
# building 174
# building 174
# building 174
# building 175
# building 175
# building 175
# building 175
# building 176
# building 176
# building 176
# building 176
# building 177
# building 177
# building 177
# building 177
# building 178
# building 178
# building 178
# building 178
# building 179
# building 179
# building 179
# building 179
# building 180
# building 180
# building 180
# building 180
# building 181
# building 181
# building 181
# building 181
# building 182
# building 182
# building 182
# building 182
# building 183
# building 183
# building 183
# building 183
# building 184
# building 184
# building 184
# building 184
# building 185
# building 185
# building 185
# building 185
# building 186
# building 186
# building 186
# building 186
# building 187
# building 187
# building 187
# building 187
# building 188
# building 188
# building 188
# building 188
# building 189
# building 189
# building 189
# building 189
# building 190
# building 190
# building 190
# building 190
# building 191
# building 191
# building 191
# building 191
# building 192
# building 192
# building 192
# building 192
# building 193
# building 193
# building 193
# building 193
# building 194
# building 194
# building 194
# building 194
# building 195
# building 195
# building 195
# building 195
# building 196
# building 196
# building 196
# building 196
# building 197
# building 197
# building 197
# building 197
# building 198
# building 198
# building 198
# building 198
# saved
# building 199
# building 199
# building 199
# building 199
# building 200
# building 200
# building 200
# building 200
# building 201
# building 201
# building 201
# building 201
# building 202
# building 202
# building 202
# building 202
# building 203
# building 203
# building 203
# building 203
# building 204
# building 204
# building 204
# building 204
# building 205
# building 205
# building 205
# building 205
# building 206
# building 206
# building 206
# building 206
# building 207
# building 207
# building 207
# building 207
# building 208
# building 208
# building 208
# building 208
# building 209
# building 209
# building 209
# building 209
# building 210
# building 210
# building 210
# building 210
# building 211
# building 211
# building 211
# building 211
# building 212
# building 212
# building 212
# building 212
# building 213
# building 213
# building 213
# building 213
# building 214
# building 214
# building 214
# building 214
# building 215
# building 215
# building 215
# building 215
# building 216
# building 216
# building 216
# building 216
# building 217
# building 217
# building 217
# building 217
# building 218
# building 218
# building 218
# building 218
# building 219
# building 219
# building 219
# building 219
# building 220
# building 220
# building 220
# building 220
# building 221
# building 221
# building 221
# building 221
# building 222
# building 222
# building 222
# building 222
# building 223
# building 223
# building 223
# building 223
# building 224
# building 224
# building 224
# building 224
# building 225
# building 225
# building 225
# building 225
# building 226
# building 226
# building 226
# building 226
# building 227
# building 227
# building 227
# building 227
# building 228
# building 228
# building 228
# building 228
# building 229
# building 229
# building 229
# building 229
# building 230
# building 230
# building 230
# building 230
# building 231
# building 231
# building 231
# building 231
# building 232
# building 232
# building 232
# building 232
# building 233
# building 233
# building 233
# building 233
# building 234
# building 234
# building 234
# building 234
# building 235
# building 235
# building 235
# building 235
# building 236
# building 236
# building 236
# building 236
# building 237
# building 237
# building 237
# building 237
# building 238
# building 238
# building 238
# building 238
# building 239
# building 239
# building 239
# building 239
# building 240
# building 240
# building 240
# building 240
# building 241
# building 241
# building 241
# building 241
# building 242
# building 242
# building 242
# building 242
# building 243
# building 243
# building 243
# building 243
# building 244
# building 244
# building 244
# building 244
# building 245
# building 245
# building 245
# building 245
# building 246
# building 246
# building 246
# building 246
# building 247
# building 247
# building 247
# building 247
# building 248
# building 248
# building 248
# building 248
# saved
# building 249
# building 249
# building 249
# building 249
# building 250
# building 250
# building 250
# building 250
# building 251
# building 251
# building 251
# building 251
# building 252
# building 252
# building 252
# building 252
# building 253
# building 253
# building 253
# building 253
# building 254
# building 254
# building 254
# building 254
# building 255
# building 255
# building 255
# building 255
# building 256
# building 256
# building 256
# building 256
# building 257
# building 257
# building 257
# building 257
# building 258
# building 258
# building 258
# building 258
# building 259
# building 259
# building 259
# building 259
# building 260
# building 260
# building 260
# building 260
# building 261
# building 261
# building 261
# building 261
# building 262
# building 262
# building 262
# building 262
# building 263
# building 263
# building 263
# building 263
# building 264
# building 264
# building 264
# building 264
# building 265
# building 265
# building 265
# building 265
# building 266
# building 266
# building 266
# building 266
# building 267
# building 267
# building 267
# building 267
# building 268
# building 268
# building 268
# building 268
# building 269
# building 269
# building 269
# building 269
# building 270
# building 270
# building 270
# building 270
# building 271
# building 271
# building 271
# building 271
# building 272
# building 272
# building 272
# building 272
# building 273
# building 273
# building 273
# building 273
# building 274
# building 274
# building 274
# building 274
# building 275
# building 275
# building 275
# building 275
# building 276
# building 276
# building 276
# building 276
# building 277
# building 277
# building 277
# building 277
# building 278
# building 278
# building 278
# building 278
# building 279
# building 279
# building 279
# building 279
# building 280
# building 280
# building 280
# building 280
# building 281
# building 281
# building 281
# building 281
# building 282
# building 282
# building 282
# building 282
# building 283
# building 283
# building 283
# building 283
# building 284
# building 284
# building 284
# building 284
# building 285
# building 285
# building 285
# building 285
# building 286
# building 286
# building 286
# building 286
# building 287
# building 287
# building 287
# building 287
# building 288
# building 288
# building 288
# building 288
# building 289
# building 289
# building 289
# building 289
# building 290
# building 290
# building 290
# building 290
# building 291
# building 291
# building 291
# building 291
# building 292
# building 292
# building 292
# building 292
# building 293
# building 293
# building 293
# building 293
# building 294
# building 294
# building 294
# building 294
# building 295
# building 295
# building 295
# building 295
# building 296
# building 296
# building 296
# building 296
# building 297
# building 297
# building 297
# building 297
# building 298
# building 298
# building 298
# building 298
# saved
# building 299
# building 299
# building 299
# building 299
# building 300
# building 300
# building 300
# building 300
# building 301
# building 301
# building 301
# building 301
# building 302
# building 302
# building 302
# building 302
# building 303
# building 303
# building 303
# building 303
# building 304
# building 304
# building 304
# building 304
# building 305
# building 305
# building 305
# building 305
# building 306
# building 306
# building 306
# building 306
# building 307
# building 307
# building 307
# building 307
# building 308
# building 308
# building 308
# building 308
# building 309
# building 309
# building 309
# building 309
# building 310
# building 310
# building 310
# building 310
# building 311
# building 311
# building 311
# building 311
# building 312
# building 312
# building 312
# building 312
# building 313
# building 313
# building 313
# building 313
# building 314
# building 314
# building 314
# building 314
# building 315
# building 315
# building 315
# building 315
# building 316
# building 316
# building 316
# building 316
# building 317
# building 317
# building 317
# building 317
# building 318
# building 318
# building 318
# building 318
# building 319
# building 319
# building 319
# building 319
# building 320
# building 320
# building 320
# building 320
# building 321
# building 321
# building 321
# building 321
# building 322
# building 322
# building 322
# building 322
# building 323
# building 323
# building 323
# building 323
# building 324
# building 324
# building 324
# building 324
# building 325
# building 325
# building 325
# building 325
# building 326
# building 326
# building 326
# building 326
# building 327
# building 327
# building 327
# building 327
# building 328
# building 328
# building 328
# building 328
# building 329
# building 329
# building 329
# building 329
# building 330
# building 330
# building 330
# building 330
# building 331
# building 331
# building 331
# building 331
# building 332
# building 332
# building 332
# building 332
# building 333
# building 333
# building 333
# building 333
# building 334
# building 334
# building 334
# building 334
# building 335
# building 335
# building 335
# building 335
# building 336
# building 336
# building 336
# building 336
# building 337
# building 337
# building 337
# building 337
# building 338
# building 338
# building 338
# building 338
# building 339
# building 339
# building 339
# building 339
# building 340
# building 340
# building 340
# building 340
# building 341
# building 341
# building 341
# building 341
# building 342
# building 342
# building 342
# building 342
# building 343
# building 343
# building 343
# building 343
# building 344
# building 344
# building 344
# building 344
# building 345
# building 345
# building 345
# building 345
# building 346
# building 346
# building 346
# building 346
# building 347
# building 347
# building 347
# building 347
# building 348
# building 348
# building 348
# building 348
# saved
# building 349
# building 349
# building 349
# building 349
# building 350
# building 350
# building 350
# building 350
# building 351
# building 351
# building 351
# building 351
# building 352
# building 352
# building 352
# building 352
# building 353
# building 353
# building 353
# building 353
# building 354
# building 354
# building 354
# building 354
# building 355
# building 355
# building 355
# building 355
# building 356
# building 356
# building 356
# building 356
# building 357
# building 357
# building 357
# building 357
# building 358
# building 358
# building 358
# building 358
# building 359
# building 359
# building 359
# building 359
# building 360
# building 360
# building 360
# building 360
# building 361
# building 361
# building 361
# building 361
# building 362
# building 362
# building 362
# building 362
# building 363
# building 363
# building 363
# building 363
# building 364
# building 364
# building 364
# building 364
# building 365
# building 365
# building 365
# building 365
# building 366
# building 366
# building 366
# building 366
# building 367
# building 367
# building 367
# building 367
# building 368
# building 368
# building 368
# building 368
# building 369
# building 369
# building 369
# building 369
# building 370
# building 370
# building 370
# building 370
# building 371
# building 371
# building 371
# building 371
# building 372
# building 372
# building 372
# building 372
# building 373
# building 373
# building 373
# building 373
# building 374
# building 374
# building 374
# building 374
# building 375
# building 375
# building 375
# building 375
# building 376
# building 376
# building 376
# building 376
# building 377
# building 377
# building 377
# building 377
# building 378
# building 378
# building 378
# building 378
# building 379
# building 379
# building 379
# building 379
# building 380
# building 380
# building 380
# building 380
# building 381
# building 381
# building 381
# building 381
# building 382
# building 382
# building 382
# building 382
# building 383
# building 383
# building 383
# building 383
# building 384
# building 384
# building 384
# building 384
# building 385
# building 385
# building 385
# building 385
# building 386
# building 386
# building 386
# building 386
# building 387
# building 387
# building 387
# building 387
# building 388
# building 388
# building 388
# building 388
# building 389
# building 389
# building 389
# building 389
# building 390
# building 390
# building 390
# building 390
# building 391
# building 391
# building 391
# building 391
# building 392
# building 392
# building 392
# building 392
# building 393
# building 393
# building 393
# building 393
# building 394
# building 394
# building 394
# building 394
# building 395
# building 395
# building 395
# building 395
# building 396
# building 396
# building 396
# building 396
# building 397
# building 397
# building 397
# building 397
# building 398
# building 398
# building 398
# building 398
# saved
# building 399
# building 399
# building 399
# building 399
# building 400
# building 400
# building 400
# building 400
# building 401
# building 401
# building 401
# building 401
# building 402
# building 402
# building 402
# building 402
# building 403
# building 403
# building 403
# building 403
# building 404
# building 404
# building 404
# building 404
# building 405
# building 405
# building 405
# building 405
# building 406
# building 406
# building 406
# building 406
# building 407
# building 407
# building 407
# building 407
# building 408
# building 408
# building 408
# building 408
# building 409
# building 409
# building 409
# building 409
# building 410
# building 410
# building 410
# building 410
# building 411
# building 411
# building 411
# building 411
# building 412
# building 412
# building 412
# building 412
# building 413
# building 413
# building 413
# building 413
# building 414
# building 414
# building 414
# building 414
# building 415
# building 415
# building 415
# building 415
# building 416
# building 416
# building 416
# building 416
# building 417
# building 417
# building 417
# building 417
# building 418
# building 418
# building 418
# building 418
# building 419
# building 419
# building 419
# building 419
# building 420
# building 420
# building 420
# building 420
# building 421
# building 421
# building 421
# building 421
# building 422
# building 422
# building 422
# building 422
# building 423
# building 423
# building 423
# building 423
# building 424
# building 424
# building 424
# building 424
# building 425
# building 425
# building 425
# building 425
# building 426
# building 426
# building 426
# building 426
# building 427
# building 427
# building 427
# building 427
# building 428
# building 428
# building 428
# building 428
# building 429
# building 429
# building 429
# building 429
# building 430
# building 430
# building 430
# building 430
# building 431
# building 431
# building 431
# building 431
# building 432
# building 432
# building 432
# building 432
# building 433
# building 433
# building 433
# building 433
# building 434
# building 434
# building 434
# building 434
# building 435
# building 435
# building 435
# building 435
# building 436
# building 436
# building 436
# building 436
# building 437
# building 437
# building 437
# building 437
# building 438
# building 438
# building 438
# building 438
# building 439
# building 439
# building 439
# building 439
# building 440
# building 440
# building 440
# building 440
# building 441
# building 441
# building 441
# building 441
# building 442
# building 442
# building 442
# building 442
# building 443
# building 443
# building 443
# building 443
# building 444
# building 444
# building 444
# building 444
# building 445
# building 445
# building 445
# building 445
# building 446
# building 446
# building 446
# building 446
# building 447
# building 447
# building 447
# building 447
# building 448
# building 448
# building 448
# building 448
# saved
# building 449
# building 449
# building 449
# building 449
# building 450
# building 450
# building 450
# building 450
# building 451
# building 451
# building 451
# building 451
# building 452
# building 452
# building 452
# building 452
# building 453
# building 453
# building 453
# building 453
# building 454
# building 454
# building 454
# building 454
# building 455
# building 455
# building 455
# building 455
# building 456
# building 456
# building 456
# building 456
# building 457
# building 457
# building 457
# building 457
# building 458
# building 458
# building 458
# building 458
# building 459
# building 459
# building 459
# building 459
# building 460
# building 460
# building 460
# building 460
# building 461
# building 461
# building 461
# building 461
# building 462
# building 462
# building 462
# building 462
# building 463
# building 463
# building 463
# building 463
# building 464
# building 464
# building 464
# building 464
# building 465
# building 465
# building 465
# building 465
# building 466
# building 466
# building 466
# building 466
# building 467
# building 467
# building 467
# building 467
# building 468
# building 468
# building 468
# building 468
# building 469
# building 469
# building 469
# building 469
# building 470
# building 470
# building 470
# building 470
# building 471
# building 471
# building 471
# building 471
# building 472
# building 472
# building 472
# building 472
# building 473
# building 473
# building 473
# building 473
# building 474
# building 474
# building 474
# building 474
# building 475
# building 475
# building 475
# building 475
# building 476
# building 476
# building 476
# building 476
# building 477
# building 477
# building 477
# building 477
# building 478
# building 478
# building 478
# building 478
# building 479
# building 479
# building 479
# building 479
# building 480
# building 480
# building 480
# building 480
# building 481
# building 481
# building 481
# building 481
# building 482
# building 482
# building 482
# building 482
# building 483
# building 483
# building 483
# building 483
# building 484
# building 484
# building 484
# building 484
# building 485
# building 485
# building 485
# building 485
# building 486
# building 486
# building 486
# building 486
# building 487
# building 487
# building 487
# building 487
# building 488
# building 488
# building 488
# building 488
# building 489
# building 489
# building 489
# building 489
# building 490
# building 490
# building 490
# building 490
# building 491
# building 491
# building 491
# building 491
# building 492
# building 492
# building 492
# building 492
# building 493
# building 493
# building 493
# building 493
# building 494
# building 494
# building 494
# building 494
# building 495
# building 495
# building 495
# building 495
# building 496
# building 496
# building 496
# building 496
# building 497
# building 497
# building 497
# building 497
# building 498
# building 498
# building 498
# building 498
# saved
# building 499
# building 499
# building 499
# building 499
# building 500
# building 500
# building 500
# building 500
# building 501
# building 501
# building 501
# building 501
# building 502
# building 502
# building 502
# building 502
# building 503
# building 503
# building 503
# building 503
# building 504
# building 504
# building 504
# building 504
# building 505
# building 505
# building 505
# building 505
# building 506
# building 506
# building 506
# building 506
# building 507
# building 507
# building 507
# building 507
# building 508
# building 508
# building 508
# building 508
# building 509
# building 509
# building 509
# building 509
# building 510
# building 510
# building 510
# building 510
# building 511
# building 511
# building 511
# building 511
# building 512
# building 512
# building 512
# building 512
# building 513
# building 513
# building 513
# building 513
# building 514
# building 514
# building 514
# building 514
# building 515
# building 515
# building 515
# building 515
# building 516
# building 516
# building 516
# building 516
# building 517
# building 517
# building 517
# building 517
# building 518
# building 518
# building 518
# building 518
# building 519
# building 519
# building 519
# building 519
# building 520
# building 520
# building 520
# building 520
# building 521
# building 521
# building 521
# building 521
# building 522
# building 522
# building 522
# building 522
# building 523
# building 523
# building 523
# building 523
# building 524
# building 524
# building 524
# building 524
# building 525
# building 525
# building 525
# building 525
# building 526
# building 526
# building 526
# building 526
# building 527
# building 527
# building 527
# building 527
# building 528
# building 528
# building 528
# building 528
# building 529
# building 529
# building 529
# building 529
# building 530
# building 530
# building 530
# building 530
# building 531
# building 531
# building 531
# building 531
# building 532
# building 532
# building 532
# building 532
# building 533
# building 533
# building 533
# building 533
# building 534
# building 534
# building 534
# building 534
# building 535
# building 535
# building 535
# building 535
# building 536
# building 536
# building 536
# building 536
# building 537
# building 537
# building 537
# building 537
# building 538
# building 538
# building 538
# building 538
# building 539
# building 539
# building 539
# building 539
# building 540
# building 540
# building 540
# building 540
# building 541
# building 541
# building 541
# building 541
# building 542
# building 542
# building 542
# building 542
# building 543
# building 543
# building 543
# building 543
# building 544
# building 544
# building 544
# building 544
# building 545
# building 545
# building 545
# building 545
# building 546
# building 546
# building 546
# building 546
# building 547
# building 547
# building 547
# building 547
# building 548
# building 548
# building 548
# building 548
# saved
# building 549
# building 549
# building 549
# building 549
# building 550
# building 550
# building 550
# building 550
# building 551
# building 551
# building 551
# building 551
# building 552
# building 552
# building 552
# building 552
# building 553
# building 553
# building 553
# building 553
# building 554
# building 554
# building 554
# building 554
# building 555
# building 555
# building 555
# building 555
# building 556
# building 556
# building 556
# building 556
# building 557
# building 557
# building 557
# building 557
# building 558
# building 558
# building 558
# building 558
# building 559
# building 559
# building 559
# building 559
# building 560
# building 560
# building 560
# building 560
# building 561
# building 561
# building 561
# building 561
# building 562
# building 562
# building 562
# building 562
# building 563
# building 563
# building 563
# building 563
# building 564
# building 564
# building 564
# building 564
# building 565
# building 565
# building 565
# building 565
# building 566
# building 566
# building 566
# building 566
# building 567
# building 567
# building 567
# building 567
# building 568
# building 568
# building 568
# building 568
# building 569
# building 569
# building 569
# building 569
# building 570
# building 570
# building 570
# building 570
# building 571
# building 571
# building 571
# building 571
# building 572
# building 572
# building 572
# building 572
# building 573
# building 573
# building 573
# building 573
# building 574
# building 574
# building 574
# building 574
# building 575
# building 575
# building 575
# building 575
# building 576
# building 576
# building 576
# building 576
# building 577
# building 577
# building 577
# building 577
# building 578
# building 578
# building 578
# building 578
# building 579
# building 579
# building 579
# building 579
# building 580
# building 580
# building 580
# building 580
# building 581
# building 581
# building 581
# building 581
# building 582
# building 582
# building 582
# building 582
# building 583
# building 583
# building 583
# building 583
# building 584
# building 584
# building 584
# building 584
# building 585
# building 585
# building 585
# building 585
# building 586
# building 586
# building 586
# building 586
# building 587
# building 587
# building 587
# building 587
# building 588
# building 588
# building 588
# building 588
# building 589
# building 589
# building 589
# building 589
# building 590
# building 590
# building 590
# building 590
# building 591
# building 591
# building 591
# building 591
# building 592
# building 592
# building 592
# building 592
# building 593
# building 593
# building 593
# building 593
# building 594
# building 594
# building 594
# building 594
# building 595
# building 595
# building 595
# building 595
# building 596
# building 596
# building 596
# building 596
# building 597
# building 597
# building 597
# building 597
# building 598
# building 598
# building 598
# building 598
# saved
# building 599
# building 599
# building 599
# building 599
# building 600
# building 600
# building 600
# building 600
# building 601
# building 601
# building 601
# building 601
# building 602
# building 602
# building 602
# building 602
# building 603
# building 603
# building 603
# building 603
# building 604
# building 604
# building 604
# building 604
# building 605
# building 605
# building 605
# building 605
# building 606
# building 606
# building 606
# building 606
# building 607
# building 607
# building 607
# building 607
# building 608
# building 608
# building 608
# building 608
# building 609
# building 609
# building 609
# building 609
# building 610
# building 610
# building 610
# building 610
# building 611
# building 611
# building 611
# building 611
# building 612
# building 612
# building 612
# building 612
# building 613
# building 613
# building 613
# building 613
# building 614
# building 614
# building 614
# building 614
# building 615
# building 615
# building 615
# building 615
# building 616
# building 616
# building 616
# building 616
# building 617
# building 617
# building 617
# building 617
# building 618
# building 618
# building 618
# building 618
# building 619
# building 619
# building 619
# building 619
# building 620
# building 620
# building 620
# building 620
# building 621
# building 621
# building 621
# building 621
# building 622
# building 622
# building 622
# building 622
# building 623
# building 623
# building 623
# building 623
# building 624
# building 624
# building 624
# building 624
# building 625
# building 625
# building 625
# building 625
# building 626
# building 626
# building 626
# building 626
# building 627
# building 627
# building 627
# building 627
# building 628
# building 628
# building 628
# building 628
# building 629
# building 629
# building 629
# building 629
# building 630
# building 630
# building 630
# building 630
# building 631
# building 631
# building 631
# building 631
# building 632
# building 632
# building 632
# building 632
# building 633
# building 633
# building 633
# building 633
# building 634
# building 634
# building 634
# building 634
# building 635
# building 635
# building 635
# building 635
# building 636
# building 636
# building 636
# building 636
# building 637
# building 637
# building 637
# building 637
# building 638
# building 638
# building 638
# building 638
# building 639
# building 639
# building 639
# building 639
# building 640
# building 640
# building 640
# building 640
# building 641
# building 641
# building 641
# building 641
# building 642
# building 642
# building 642
# building 642
# building 643
# building 643
# building 643
# building 643
# building 644
# building 644
# building 644
# building 644
# building 645
# building 645
# building 645
# building 645
# building 646
# building 646
# building 646
# building 646
# building 647
# building 647
# building 647
# building 647
# building 648
# building 648
# building 648
# building 648
# saved
# building 649
# building 649
# building 649
# building 649
# building 650
# building 650
# building 650
# building 650
# building 651
# building 651
# building 651
# building 651
# building 652
# building 652
# building 652
# building 652
# building 653
# building 653
# building 653
# building 653
# building 654
# building 654
# building 654
# building 654
# building 655
# building 655
# building 655
# building 655
# building 656
# building 656
# building 656
# building 656
# building 657
# building 657
# building 657
# building 657
# building 658
# building 658
# building 658
# building 658
# building 659
# building 659
# building 659
# building 659
# building 660
# building 660
# building 660
# building 660
# building 661
# building 661
# building 661
# building 661
# building 662
# building 662
# building 662
# building 662
# building 663
# building 663
# building 663
# building 663
# building 664
# building 664
# building 664
# building 664
# building 665
# building 665
# building 665
# building 665
# building 666
# building 666
# building 666
# building 666
# building 667
# building 667
# building 667
# building 667
# building 668

# %%
rrr = pd.read_csv("resufin.csv")

# %%
print(len(rrr['row_id'].unique()) - len(rrr.index))
print(len(rrr))

# %%
rrr = rrr.fillna(350)
print(len(rrr['row_id'].unique()) - len(rrr.index))

# %%
rrr.to_csv("resufin1.csv",index=False)

# %%
rrr
